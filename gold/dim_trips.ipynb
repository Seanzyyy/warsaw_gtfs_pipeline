# %%
# %sql
CREATE OR REPLACE TABLE warsaw_gtfs.gold.dim_trips AS
SELECT 
trip_id,
block_short_name AS block_number,
trip_headsign AS vehicle_headsign,
trip_short_name,
wheelchair_accessible,
trip_variant
FROM warsaw_gtfs.silver.trips
