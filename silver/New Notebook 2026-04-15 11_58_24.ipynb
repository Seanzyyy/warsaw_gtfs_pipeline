# %%
# %sql
SELECT * FROM warsaw_gtfs.silver.stop_times WHERE trip_id LIKE 'M1%' OR trip_id LIKE 'M2%'

# %%
# %sql
SELECT * FROM warsaw_gtfs.silver.stops WHERE stop_id == '6059M:P1'

# %%
# %sql
SELECT * FROM warsaw_gtfs.silver.trips WHERE trip_id LIKE 'M1%' OR trip_id LIKE 'M2%'
