# %% [markdown]
# #1. Extract shapes table from bronze layer

# %%
df = spark.table('warsaw_gtfs.bronze.shapes')

# %%
df.display()

# %% [markdown]
# #2. Data integrity checks

# %%
import pyspark.sql.functions as F
df.filter('shape_dist_traveled is null').display()

# %% [markdown]
# #.3. Load shapes dataframe to silver layer

# %%
df.write.mode('overwrite').saveAsTable('warsaw_gtfs.silver.shapes')
