# %% [markdown]
# #1. Load frequencies data from bronze

# %%
df = spark.table('warsaw_gtfs.bronze.frequencies')

# %%
df.display()

# %%
# null checks
df.filter('trip_id is null').display()

# %% [markdown]
# #2. Load data to silver layer

# %%
df.write.mode('overwrite').format('delta').saveAsTable('warsaw_gtfs.silver.frequencies')
